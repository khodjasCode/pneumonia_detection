# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
'''for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))'''

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# "for dirname, _, filenames in os.walk('/kaggle/input'):\n    for filename in filenames:\n        print(os.path.join(dirname, filename))"

# %%
import torchvision.models as models
import fastai
import torch
from fastai.vision.all import *

# %%
sample_sol = pd.read_csv('/kaggle/input/pnevmoniya/sample_solution.csv')
sample_sol
# Out:
#                       id  labels
# 0    test_img_10001.jpeg       0
# 1    test_img_10002.jpeg       0
# 2    test_img_10003.jpeg       0
# 3    test_img_10004.jpeg       0
# 4    test_img_10005.jpeg       0
# ..                   ...     ...
# 619  test_img_10620.jpeg       0
# 620  test_img_10621.jpeg       0
# 621  test_img_10622.jpeg       0
# 622  test_img_10623.jpeg       0
# 623  test_img_10624.jpeg       0
#
# [624 rows x 2 columns]

# %%
path = Path('/kaggle/input/pnevmoniya')
path.ls()
# Out:
# (#3) [Path('/kaggle/input/pnevmoniya/test'),Path('/kaggle/input/pnevmoniya/train'),Path('/kaggle/input/pnevmoniya/sample_solution.csv')]

# %%
pnev_train = (path/'train'/'PNEUMONIA').ls().sorted()
pnev_train
# Out:
# (#3875) [Path('/kaggle/input/pnevmoniya/train/PNEUMONIA/person1000_bacteria_2931.jpeg'),Path('/kaggle/input/pnevmoniya/train/PNEUMONIA/person1000_virus_1681.jpeg'),Path('/kaggle/input/pnevmoniya/train/PNEUMONIA/person1001_bacteria_2932.jpeg'),Path('/kaggle/input/pnevmoniya/train/PNEUMONIA/person1002_bacteria_2933.jpeg'),Path('/kaggle/input/pnevmoniya/train/PNEUMONIA/person1003_bacteria_2934.jpeg'),Path('/kaggle/input/pnevmoniya/train/PNEUMONIA/person1003_virus_1685.jpeg'),Path('/kaggle/input/pnevmoniya/train/PNEUMONIA/person1004_bacteria_2935.jpeg'),Path('/kaggle/input/pnevmoniya/train/PNEUMONIA/person1004_virus_1686.jpeg'),Path('/kaggle/input/pnevmoniya/train/PNEUMONIA/person1005_bacteria_2936.jpeg'),Path('/kaggle/input/pnevmoniya/train/PNEUMONIA/person1005_virus_1688.jpeg'),Path('/kaggle/input/pnevmoniya/train/PNEUMONIA/person1006_bacteria_2937.jpeg'),Path('/kaggle/input/pnevmoniya/train/PNEUMONIA/person1007_bacteria_2938.jpeg'),Path('/kaggle/input/pnevmoniya/train/PNEUMONIA/person
# ...

# %%
norm_train = (path/'train'/'NORMAL').ls().sorted()
norm_train
# Out:
# (#1341) [Path('/kaggle/input/pnevmoniya/train/NORMAL/IM-0115-0001.jpeg'),Path('/kaggle/input/pnevmoniya/train/NORMAL/IM-0117-0001.jpeg'),Path('/kaggle/input/pnevmoniya/train/NORMAL/IM-0119-0001.jpeg'),Path('/kaggle/input/pnevmoniya/train/NORMAL/IM-0122-0001.jpeg'),Path('/kaggle/input/pnevmoniya/train/NORMAL/IM-0125-0001.jpeg'),Path('/kaggle/input/pnevmoniya/train/NORMAL/IM-0127-0001.jpeg'),Path('/kaggle/input/pnevmoniya/train/NORMAL/IM-0128-0001.jpeg'),Path('/kaggle/input/pnevmoniya/train/NORMAL/IM-0129-0001.jpeg'),Path('/kaggle/input/pnevmoniya/train/NORMAL/IM-0131-0001.jpeg'),Path('/kaggle/input/pnevmoniya/train/NORMAL/IM-0133-0001.jpeg'),Path('/kaggle/input/pnevmoniya/train/NORMAL/IM-0135-0001.jpeg'),Path('/kaggle/input/pnevmoniya/train/NORMAL/IM-0137-0001.jpeg'),Path('/kaggle/input/pnevmoniya/train/NORMAL/IM-0140-0001.jpeg'),Path('/kaggle/input/pnevmoniya/train/NORMAL/IM-0141-0001.jpeg'),Path('/kaggle/input/pnevmoniya/train/NORMAL/IM-0143-0001.jpeg'),Path('/kaggle/input/pnevmoniy
# ...

# %%
example = norm_train[33]
example_o = Image.open(example)
example_o

# %%
illness = DataBlock(
    blocks = (ImageBlock, CategoryBlock),
    get_items = get_image_files,
    splitter = RandomSplitter(valid_pct=0.1, seed=12),
    get_y = parent_label,
    item_tfms = Resize(224)
)

# %%
dls = illness.dataloaders(path/'train')

# %%
model = resnet34

# %%
learn = vision_learner(dls, model, metrics=accuracy, pretrained=False)
learn.model.load_state_dict(torch.load('/kaggle/input/resnet34/resnet34-b627a593.pth', weights_only=True), strict=False)
# Out:
# _IncompatibleKeys(missing_keys=['0.0.weight', '0.1.weight', '0.1.bias', '0.1.running_mean', '0.1.running_var', '0.4.0.conv1.weight', '0.4.0.bn1.weight', '0.4.0.bn1.bias', '0.4.0.bn1.running_mean', '0.4.0.bn1.running_var', '0.4.0.conv2.weight', '0.4.0.bn2.weight', '0.4.0.bn2.bias', '0.4.0.bn2.running_mean', '0.4.0.bn2.running_var', '0.4.1.conv1.weight', '0.4.1.bn1.weight', '0.4.1.bn1.bias', '0.4.1.bn1.running_mean', '0.4.1.bn1.running_var', '0.4.1.conv2.weight', '0.4.1.bn2.weight', '0.4.1.bn2.bias', '0.4.1.bn2.running_mean', '0.4.1.bn2.running_var', '0.4.2.conv1.weight', '0.4.2.bn1.weight', '0.4.2.bn1.bias', '0.4.2.bn1.running_mean', '0.4.2.bn1.running_var', '0.4.2.conv2.weight', '0.4.2.bn2.weight', '0.4.2.bn2.bias', '0.4.2.bn2.running_mean', '0.4.2.bn2.running_var', '0.5.0.conv1.weight', '0.5.0.bn1.weight', '0.5.0.bn1.bias', '0.5.0.bn1.running_mean', '0.5.0.bn1.running_var', '0.5.0.conv2.weight', '0.5.0.bn2.weight', '0.5.0.bn2.bias', '0.5.0.bn2.running_mean', '0.5.0.bn2.running_var',
# ...

# %%
learn.fine_tune(2)
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.191459</td>
#       <td>0.150260</td>
#       <td>0.938580</td>
#       <td>16:59</td>
# ...

# %%
learn.validate()[1]
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# 0.9596928954124451

# %%
labels = []
for index, row in sample_sol.iterrows():
    image_path = Path(f"/kaggle/input/pnevmoniya/test/{row['id']}")
    img = PILImage.create(image_path)
    prediction = learn.predict(img)
    label = prediction[2][1].item()
    labels.append(label)
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
# ...

# %%
labels = [1 if label > 0.5 else 0 for label in labels]
sample_sol['labels'] = labels

# %%
sample_sol
# Out:
#                       id  labels
# 0    test_img_10001.jpeg       1
# 1    test_img_10002.jpeg       0
# 2    test_img_10003.jpeg       1
# 3    test_img_10004.jpeg       1
# 4    test_img_10005.jpeg       0
# ..                   ...     ...
# 619  test_img_10620.jpeg       1
# 620  test_img_10621.jpeg       0
# 621  test_img_10622.jpeg       1
# 622  test_img_10623.jpeg       1
# 623  test_img_10624.jpeg       1
#
# [624 rows x 2 columns]

# %%
sample_sol.to_csv('submission.csv', index=False)
